# %% [markdown]
# <div style="background:#1e1e2e; padding:16px 20px; border-radius:8px; font-family:monospace; color:#cdd6f4; line-height:1.8">
#
#   <p style="margin:0 0 16px 0; color:#cba6f7; font-weight:bold; font-size:1.05em;">🐍 Core Python Foundations — 10-Session Track</p>
#   <p style="margin:0 0 16px 0; color:#a6adc8;">One concept per session, gone deep. Each session: 3 parts, delivered one at a time.</p>
#
#   <table style="width:100%; border-collapse:collapse; margin:0 0 20px 0; font-size:0.92em;">
#     <thead>
#       <tr style="border-bottom:2px solid #cba6f7;">
#         <th style="text-align:center; padding:8px 12px; color:#cba6f7; width:6%">#</th>
#         <th style="text-align:left; padding:8px 12px; color:#cba6f7; width:30%">Topic</th>
#         <th style="text-align:left; padding:8px 12px; color:#cba6f7;">What you'll internalize</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr style="border-bottom:1px solid #313244;">
#         <td style="padding:7px 12px; text-align:center; color:#cba6f7; font-weight:bold;">1</td>
#         <td style="padding:7px 12px; color:#89b4fa;">Mutability &amp; the object model</td>
#         <td style="padding:7px 12px;">Names, objects, references — <code>is</code> vs <code>==</code>, <code>id()</code>, identity model</td>
#       </tr>
#       <tr style="border-bottom:1px solid #313244; background:#25253a;">
#         <td style="padding:7px 12px; text-align:center; color:#cba6f7; font-weight:bold;">2</td>
#         <td style="padding:7px 12px; color:#89b4fa;">Sequences deep</td>
#         <td style="padding:7px 12px;">list, tuple, set, dict internals + time/space complexity of every common op</td>
#       </tr>
#       <tr style="border-bottom:1px solid #313244;">
#         <td style="padding:7px 12px; text-align:center; color:#cba6f7; font-weight:bold;">3</td>
#         <td style="padding:7px 12px; color:#89b4fa;">Strings</td>
#         <td style="padding:7px 12px;">Immutability as a sequence, methods, f-strings, formatting — heavy interview territory</td>
#       </tr>
#       <tr style="border-bottom:1px solid #313244; background:#25253a;">
#         <td style="padding:7px 12px; text-align:center; color:#cba6f7; font-weight:bold;">4</td>
#         <td style="padding:7px 12px; color:#89b4fa;">Comprehensions &amp; generators</td>
#         <td style="padding:7px 12px;">list/dict/set comprehensions, generator expressions, <code>yield</code>, lazy evaluation</td>
#       </tr>
#       <tr style="border-bottom:1px solid #313244;">
#         <td style="padding:7px 12px; text-align:center; color:#cba6f7; font-weight:bold;">5</td>
#         <td style="padding:7px 12px; color:#89b4fa;">Functions, scope &amp; closures</td>
#         <td style="padding:7px 12px;">args/kwargs, default-arg traps, LEGB scope, closures, <code>if __name__ == "__main__"</code></td>
#       </tr>
#       <tr style="border-bottom:1px solid #313244; background:#25253a;">
#         <td style="padding:7px 12px; text-align:center; color:#cba6f7; font-weight:bold;">6</td>
#         <td style="padding:7px 12px; color:#89b4fa;">Decorators</td>
#         <td style="padding:7px 12px;">Function wrapping, <code>functools.wraps</code>, practical decorator patterns</td>
#       </tr>
#       <tr style="border-bottom:1px solid #313244;">
#         <td style="padding:7px 12px; text-align:center; color:#cba6f7; font-weight:bold;">7</td>
#         <td style="padding:7px 12px; color:#89b4fa;">OOP &amp; dunder methods</td>
#         <td style="padding:7px 12px;">Classes, inheritance, <code>__init__</code>/<code>__repr__</code>/<code>__eq__</code>; GIL &amp; CPU-bound threading</td>
#       </tr>
#       <tr style="border-bottom:1px solid #313244; background:#25253a;">
#         <td style="padding:7px 12px; text-align:center; color:#cba6f7; font-weight:bold;">8</td>
#         <td style="padding:7px 12px; color:#89b4fa;">Iterators &amp; context managers</td>
#         <td style="padding:7px 12px;">Iterator protocol, <code>__iter__</code>/<code>__next__</code>, <code>with</code>, <code>__enter__</code>/<code>__exit__</code></td>
#       </tr>
#       <tr style="border-bottom:1px solid #313244;">
#         <td style="padding:7px 12px; text-align:center; color:#cba6f7; font-weight:bold;">9</td>
#         <td style="padding:7px 12px; color:#89b4fa;">Error handling</td>
#         <td style="padding:7px 12px;">Exceptions, custom exception classes, try/except/else/finally, EAFP vs LBYL</td>
#       </tr>
#       <tr>
#         <td style="padding:7px 12px; text-align:center; color:#cba6f7; font-weight:bold;">10</td>
#         <td style="padding:7px 12px; color:#89b4fa;">Typing &amp; dataclasses</td>
#         <td style="padding:7px 12px;">Type hints, <code>Optional</code>/<code>Union</code>/generics, <code>@dataclass</code> — feeds clean FastAPI &amp; Pydantic code</td>
#       </tr>
#     </tbody>
#   </table>
#
#   <p style="margin:0 0 8px 0; color:#cba6f7; font-weight:bold;">Each session — 3 parts, one per response:</p>
#   <ul style="margin:0 0 14px 0; padding-left:20px; line-height:2.2">
#     <li><strong style="color:#89b4fa">Part 1</strong> — Theory → Examples → Edge Cases</li>
#     <li><strong style="color:#89b4fa">Part 2</strong> — Golden Rules → Traps → Exercise</li>
#     <li><strong style="color:#89b4fa">Part 3</strong> — ML Real-World → Interview Q&amp;A → Code Challenges → Summary Table</li>
#   </ul>
#
#   <p style="margin:0; border-left:4px solid #a6e3a1; padding-left:12px">
#     <strong style="color:#a6e3a1">Throughout:</strong> Power BI/SQL analogies where they genuinely fit, ML/interview connections woven in, summary table closing every session.
#   </p>
#
# </div>

# %% [markdown]
# <div style="background:#1e1e2e; padding:16px 20px; border-radius:8px; font-family:monospace; color:#cdd6f4; line-height:1.8">
#
#   <p style="margin:0 0 16px 0; color:#cba6f7; font-weight:bold; font-size:1.05em;">📋 Teaching Format — Locked In</p>
#
#   <p style="margin:0 0 8px 0; color:#a6e3a1; font-weight:bold;">9 Sections — Mandatory, This Order:</p>
#   <ol style="margin:0 0 18px 0; padding-left:22px; line-height:2.4">
#     <li><strong style="color:#89b4fa">THEORY</strong> — concept first, Power BI / SQL analogies as anchors</li>
#     <li><strong style="color:#89b4fa">EXAMPLE</strong> — runnable code, step by step</li>
#     <li><strong style="color:#89b4fa">EDGE CASES</strong> — 5–8 cases with code + output + why it matters</li>
#     <li><strong style="color:#89b4fa">GOLDEN RULES</strong> — production patterns to memorize</li>
#     <li><strong style="color:#89b4fa">COMMON TRAPS</strong> — bugs that bite beginners and seniors</li>
#     <li><strong style="color:#89b4fa">EXERCISE</strong> — 5 problems, easy → hard, with hints</li>
#     <li><strong style="color:#89b4fa">ML REAL-WORLD CONNECTION</strong> — feature engineering, sklearn, healthcare / fraud / recommendations</li>
#     <li><strong style="color:#89b4fa">INTERVIEW QUESTIONS</strong>
#       <ul style="margin:4px 0 0 0; padding-left:20px; line-height:2.2">
#         <li><strong style="color:#cba6f7">8a. Conceptual Q&amp;A</strong> — 10–12 questions with answers</li>
#         <li><strong style="color:#cba6f7">8b. Code Challenges</strong> — 7–10 problems, Easy/Medium/Hard mix — problem + attempt space + collapsible solution + explanation</li>
#       </ul>
#     </li>
#     <li><strong style="color:#89b4fa">SUMMARY TABLE</strong> — concept | why it matters in ML | interview frequency</li>
#   </ol>
#
#   <p style="margin:0 0 8px 0; color:#a6e3a1; font-weight:bold;">Style Rules:</p>
#   <ul style="margin:0 0 18px 0; padding-left:20px; line-height:2.2">
#     <li>Concept first, mechanics second — ML/interview connections in every section</li>
#     <li>Power BI and SQL analogies as mental anchors throughout</li>
#     <li>Code-heavy — every concept gets a runnable example</li>
#     <li>One concept per session, gone <em>deep</em> — never broad-and-shallow</li>
#     <li>Long lessons broken into parts — deliver Part 1, wait for go before Part 2</li>
#     <li>Push back honestly — verify outputs by running code when challenged</li>
#     <li>No project branding in any code, file, or examples</li>
#     <li>Direct tone — no excessive apologies or hedging</li>
#   </ul>
#
#   <p style="margin:0 0 8px 0; color:#a6e3a1; font-weight:bold;">Interaction Rules:</p>
#   <ul style="margin:0 0 18px 0; padding-left:20px; line-height:2.2">
#     <li>Ask before assuming — use the questions tool when there's a real choice to make</li>
#     <li>At lesson end: summary table + preview of the natural next lesson</li>
#     <li><code>"Quiz me with 20 code interview questions"</code> — triggers a standalone quiz session</li>
#     <li><code>"Review my notebook and give feedback"</code> — upload the file, get structured feedback</li>
#   </ul>
#
#   <p style="margin:0; border-left:4px solid #f38ba8; padding-left:12px">
#     <strong style="color:#f38ba8">Non-negotiable:</strong> every lesson hits all 9 sections, in order, every time — no skipping, no merging sections, no shortcuts.
#   </p>
#
# </div>
