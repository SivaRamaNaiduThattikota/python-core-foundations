# %% [markdown]
# <div style="background:#1e1e2e; padding:16px 20px; border-radius:8px; font-family:monospace; color:#cdd6f4; line-height:1.8"><p style="margin:0 0 8px 0; color:#cba6f7; font-weight:bold; font-size:1.05em;">📎 Session 10 — Typing &amp; Dataclasses · Hands-on</p><p style="margin:0;">Attempt space for the 12 <strong>Exercises</strong> and 8 <strong>Code Challenges</strong>. Hints in <code>theory.ipynb</code>; worked solutions in <code>solutions.ipynb</code> — try each yourself first.</p></div>

# %% [markdown]
# ### Exercises (Part 2 · §6) — 12 problems

# %%
# E1 (Easy) — Annotate greet(name) -> str
# Hint: params after `:`, return after `->`

# %%
# E2 (Easy) — Annotate mean(xs) -> float on a list
# Hint: xs: list[float]

# %%
# E3 (Easy) — first_positive(xs) -> int | None
# Hint: return None if none found

# %%
# E4 (Med) — to_int(x: int | str) -> int
# Hint: int(x) handles both

# %%
# E5 (Med) — repeat_apply(f, x, n): apply f n times, typed
# Hint: f: Callable[[int], int]

# %%
# E6 (Med) — Generic last(xs: list[T]) -> T
# Hint: T = TypeVar("T")

# %%
# E7 (Med) — Book dataclass (title, author, year); check repr/eq
# Hint: @dataclass; compare two equal Books

# %%
# E8 (Med) — Cart with items list via default_factory
# Hint: field(default_factory=list); two carts independent

# %%
# E9 (Hard) — Frozen GridCell(x, y) counted with Counter
# Hint: @dataclass(frozen=True); Counter(cells)

# %%
# E10 (Hard) — order=True Student(gpa, name); rank with sorted
# Hint: sorted(..., reverse=True); mind field order

# %%
# E11 (Hard) — TypedDict Payload(user_id, active) + reader fn
# Hint: class Payload(TypedDict): ...

# %%
# E12 (Hard) — Protocol HasName; describe(obj: HasName)
# Hint: class HasName(Protocol): name: str

# %% [markdown]
# ### Code Challenges (Part 3 · §8b) — 8 problems

# %%
# C1 (Easy) — Money(amount, currency) frozen; de-dup in a set

# %%
# C2 (Easy) — Alias JSONNum = list[float]; normalize(v) -> JSONNum

# %%
# C3 (Med) — Task(priority, label) order=True with label compare=False

# %%
# C4 (Med) — Percentage(value): __post_init__ enforces 0..100

# %%
# C5 (Med) — Generic Stack[T] with push/pop typed

# %%
# C6 (Med) — SupportsPredict Protocol; score(models, x)

# %%
# C7 (Hard) — Frozen HyperParams; with_lr(cfg, lr) via replace

# %%
# C8 (Hard) — validate(d, schema) checks TypedDict keys + isinstance types
